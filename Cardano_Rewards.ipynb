# %% [markdown]
# <a href="https://colab.research.google.com/github/ejane24/CROWD/blob/main/Cardano_Rewards.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 
import matplotlib.pyplot as plt
import numpy as np
 
a0 = 10
R = 100
k = 500
T = 31950000000
z0 =1/k

# %%
 
def rewards(a0,sigmaprime,sprime):
    f = R/(1+a0)
    f *= (sigmaprime + sprime * a0 * (sigmaprime - sprime * ((z0-sigmaprime)/z0))/z0)
    return f

# %%
 
 
for s in np.arange(0,saturation, 5000000):
    sprime=s/T
    rewardsList=[]
    for sigma in np.arange(s,saturation,100000):
        sigmaprime=sigma/T
        rewardsList.append(rewards(5,sigmaprime,sprime))
    plt.plot(np.arange(s,saturation,100000),rewardsList,label=s)
 
plt.xlabel('Total Pool Stake')
plt.ylabel('Rewards')
plt.legend()
plt.show()
